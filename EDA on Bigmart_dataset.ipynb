# %% [markdown]
# # Understanding Data
#
# 1.   Import Libraries
# 2.   Import Big Mart Dataset
# 3.   Learn about features

# %%
#import necessary libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import dataset using pandas

df = pd.read_csv('/content/drive/MyDrive/Analytics/bigmart.csv')

# %% [markdown]
# # 1. Display dataset

# %%
#display the dataset

df.head(20)
# Out:
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15        9.300          Low Fat         0.016047
# 1            DRC01        5.920          Regular         0.019278
# 2            FDN15       17.500          Low Fat         0.016760
# 3            FDX07       19.200          Regular         0.000000
# 4            NCD19        8.930          Low Fat         0.000000
# 5            FDP36       10.395          Regular         0.000000
# 6            FDO10       13.650          Regular         0.012741
# 7            FDP10          NaN          Low Fat         0.127470
# 8            FDH17       16.200          Regular         0.016687
# 9            FDU28       19.200          Regular         0.094450
# 10           FDY07       11.800          Low Fat         0.000000
# 11           FDA03       18.500          Regular         0.045464
# 12           FDX32       15.100          Regular         0.100014
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %% [markdown]
# Changing data type

# %%
df.Outlet_Establishment_Year=df.Outlet_Establishment_Year.astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   object
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), object(8)
# memory usage: 799.2+ KB

# %%
#Check the number of null entries

df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.Item_Fat_Content=df.Item_Fat_Content.astype('category')
df.Outlet_Type=df.Outlet_Type.astype('category')

# %%
print(df.dtypes)
# Out:
# Item_Identifier                object
# Item_Weight                   float64
# Item_Fat_Content             category
# Item_Visibility               float64
# Item_Type                      object
# Item_MRP                      float64
# Outlet_Identifier              object
# Outlet_Establishment_Year      object
# Outlet_Size                    object
# Outlet_Location_Type           object
# Outlet_Type                  category
# Item_Outlet_Sales             float64
# dtype: object

# %%
#describe the numerical values

df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Item_Outlet_Sales
# count  7060.000000      8523.000000  8523.000000        8523.000000
# mean     12.857645         0.066132   140.992782        2181.288914
# std       4.643456         0.051598    62.275067        1706.499616
# min       4.555000         0.000000    31.290000          33.290000
# 25%       8.773750         0.026989    93.826500         834.247400
# 50%      12.600000         0.053931   143.012800        1794.331000
# 75%      16.850000         0.094585   185.643700        3101.296400
# max      21.350000         0.328391   266.888400       13086.964800

# %%
#describe all the values

df.describe(include='all')
# Out:
#        Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# count             8523  7060.000000             8523      8523.000000
# unique            1559          NaN                5              NaN
# top              FDW13          NaN          Low Fat              NaN
# freq                10          NaN             5089              NaN
# mean               NaN    12.857645              NaN         0.066132
# std                NaN     4.643456              NaN         0.051598
# min                NaN     4.555000              NaN         0.000000
# 25%                NaN     8.773750              NaN         0.026989
# 50%                NaN    12.600000              NaN         0.053931
# 75%                NaN    16.850000              NaN         0.094585
# max                NaN    21.350000              NaN         0.328391
#
#                     Item_Type     Item_MRP Outlet_Identifier  \
# count                    8523  8523.000000              8523
# ...

# %%
# Step 1: Total number of rows
total_items = len(df)

# Step 2: Rows where Item_Visibility <= 0.05
low_visibility_count = len(df[df['Item_Visibility'] <= 0.05])

# Step 3: Calculate the percentage
percentage = (low_visibility_count / total_items) * 100

# Print the result
print(f"Percentage of items with visibility ≤ 0.05: {percentage:.2f}%")
# Out:
# Percentage of items with visibility ≤ 0.05: 47.53%

# %%
plt.figure(figsize=(20, 8))
sns.pairplot(data=df, y_vars='Item_Outlet_Sales', height=4)

# %%
plt.figure(figsize=(25, 8))
sns.barplot(data=df, x='Item_Type', y='Item_Outlet_Sales')
# Out:
# <Axes: xlabel='Item_Type', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize=(25, 8))
sns.barplot(data=df, x='Outlet_Type', y='Item_Outlet_Sales')
# Out:
# <Axes: xlabel='Outlet_Type', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize=(25, 8))
sns.boxplot(data=df, x='Outlet_Type', y='Item_Outlet_Sales')
# Out:
# <Axes: xlabel='Outlet_Type', ylabel='Item_Outlet_Sales'>

# %%
# Plot the distribution curve for 'Item_Outlet_Sales'
plt.figure(figsize=(10, 6))
sns.displot(df['Item_Outlet_Sales'], kde=True, color='blue')
plt.title('Distribution of Item_Outlet_Sales')
plt.xlabel('Item_Outlet_Sales')
plt.ylabel('Frequency')
plt.show()

# Calculate and print the skewness
skewness_value = df['Item_Outlet_Sales'].skew()
print(f"Skewness value: {round(skewness_value, 2)}")

# Determine if the distribution is right-skewed or left-skewed
if skewness_value > 0:
    print("Right-Skewed")
elif skewness_value < 0:
    print("Left-Skewed")
else:
    print("Normally Distributed")
# Out:
# Skewness value: 1.18
# Right-Skewed

# %% [markdown]
# # Variation For Mean

# %%
# Plot the distribution graph of 'Item_Visibility'
sns.displot(df['Item_Visibility'], kde=True)
plt.title("Distribution of Item_Visibility")
plt.xlabel("Item_Visibility")
plt.ylabel("Frequency")
plt.show()

# Step 1: Calculate mean
mean_visibility = df['Item_Visibility'].mean()

# Step 2: Count how many values are less than and greater than the mean
less_than_mean = (df['Item_Visibility'] < mean_visibility).sum()
greater_than_mean = (df['Item_Visibility'] > mean_visibility).sum()

# Step 3: Compare and print result
if greater_than_mean > less_than_mean:
    print("Higher")
else:
    print("Lower")
# Out:
# Lower

# %% [markdown]
# # Item Weight

# %%
# Step 1: Visualize using boxplot
sns.boxplot(x=df['Item_Weight'])
plt.title("Boxplot of Item_Weight")
plt.xlabel("Item_Weight")
plt.show()

# Step 2: Calculate IQR
Q1 = df['Item_Weight'].quantile(0.25)
Q3 = df['Item_Weight'].quantile(0.75)
IQR = Q3 - Q1

# Define outlier thresholds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Step 3: Find outliers
outliers = df[(df['Item_Weight'] < lower_bound) | (df['Item_Weight'] > upper_bound)]

# Step 4: Print the number of outliers
print(len(outliers))
# Out:
# 0

# %% [markdown]
# # Separations

# %%
# Plot histogram with 200+ bins
plt.figure(figsize=(10, 5))
plt.hist(df['Item_MRP'], bins=200, edgecolor='black')
plt.title("Distribution of Item_MRP")
plt.xlabel("Item_MRP")
plt.ylabel("Frequency")
plt.show()

# Based on visual inspection of the histogram, we manually count the peaks
# Now, just print the number of separations seen
print(4)  # Example: If we see 4 clear peaks in the histogram
# Out:
# 4

# %% [markdown]
# # Bivariate Distributions

# %% [markdown]
# # Plot Pairwise Relationship

# %%
# Set the variables for pairplot
x_vars = ["Item_Weight", "Item_Visibility", "Item_MRP"]
y_vars = ["Item_Outlet_Sales"]

# Create the pairplot
sns.pairplot(df, x_vars=x_vars, y_vars=y_vars, height=4, aspect=1, kind='scatter')
plt.show()

# %% [markdown]
# # Most Item Outlet Sales

# %%
# Step 1: Group by 'Item_Type' and sum 'Item_Outlet_Sales'
sales_by_type = df.groupby('Item_Type')['Item_Outlet_Sales'].sum().sort_values(ascending=False)

# Step 2: Plot the results using a bar plot
plt.figure(figsize=(12, 6))
sns.barplot(x=sales_by_type.index, y=sales_by_type.values, palette='viridis')
plt.xticks(rotation=45)
plt.title("Total Item Outlet Sales by Item Type")
plt.xlabel("Item Type")
plt.ylabel("Total Sales")
plt.tight_layout()
plt.show()

# Step 3: Print the item type with maximum sales
max_item_type = sales_by_type.idxmax()
print( max_item_type)
# Out:
# <ipython-input-24-c5bd4f264a2f>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sales_by_type.index, y=sales_by_type.values, palette='viridis')
# Fruits and Vegetables

# %% [markdown]
# # Least Outlet type Sales

# %%
# Step 1: Group by 'Outlet_Type' and sum 'Item_Outlet_Sales'
sales_by_outlet = df.groupby('Outlet_Type')['Item_Outlet_Sales'].sum().sort_values(ascending=False)

# Step 2: Plot the results using a bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x=sales_by_outlet.index, y=sales_by_outlet.values, palette='Set2')
plt.title("Total Item Outlet Sales by Outlet Type")
plt.xlabel("Outlet Type")
plt.ylabel("Total Sales")
plt.tight_layout()
plt.show()

# Step 3: Identify the outlet types with max and min sales
max_sales_outlet = sales_by_outlet.idxmax()
min_sales_outlet = sales_by_outlet.idxmin()

# Step 4: Print the outlet type with the least sales
print(f"Outlet type with the least number of sales: {min_sales_outlet}")
# Out:
# <ipython-input-25-2a72595f53c5>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sales_by_outlet = df.groupby('Outlet_Type')['Item_Outlet_Sales'].sum().sort_values(ascending=False)
# <ipython-input-25-2a72595f53c5>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=sales_by_outlet.index, y=sales_by_outlet.values, palette='Set2')
# Outlet type with the least number of sales: Grocery Store

# %% [markdown]
# # Outlet Comparison

# %%
# Step 1: Plot the graph using 'OutletEstablishmentYear' and 'ItemOutletSales'
plt.figure(figsize=(10, 6))
plt.scatter(df['Outlet_Establishment_Year'].astype(int), df['Item_Outlet_Sales'], alpha=0.5) #Change to int
plt.title("Item Outlet Sales vs. Outlet Establishment Year")
plt.xlabel("Outlet Establishment Year")
plt.ylabel("Item Outlet Sales")
plt.tight_layout()
plt.show()

# Step 2: Categorize outlets into old (before 2000) and new (after 2000)
old_outlets = df[df['Outlet_Establishment_Year'].astype(int) < 2000] #Change to int
new_outlets = df[df['Outlet_Establishment_Year'].astype(int) >= 2000] #Change to int

# Step 3: Calculate average sales for old and new outlets
avg_sales_old = old_outlets['Item_Outlet_Sales'].mean()
avg_sales_new = new_outlets['Item_Outlet_Sales'].mean()

# Step 4: Compare the average sales and print the result
if avg_sales_old > avg_sales_new:
    print("Yes")
else:
    print("No")
# Out:
# No

# %% [markdown]
# #Stores

# %%
# Step 1: Filter data for OUT010 and OUT019
out010_019_data = df[df['Outlet_Identifier'].isin(['OUT010', 'OUT019'])]

# Step 2: Inspect sales data for these stores
print(out010_019_data[['Outlet_Identifier', 'Item_Outlet_Sales', 'Item_Type', 'Outlet_Type', 'Item_Weight', 'Item_MRP']])

plt.figure(figsize=(12, 6))
sns.boxplot(x='Outlet_Identifier', y='Item_Outlet_Sales', data=df)
plt.title("Sales Distribution Across Outlets")
plt.show()

# Step 4: Investigate if these stores have significantly different item types or sales performance
out010_019_sales_by_type = out010_019_data.groupby('Item_Type')['Item_Outlet_Sales'].sum()
print(out010_019_sales_by_type)

# Step 5: Check if any other outlet attributes (like Item_MRP or Outlet_Establishment_Year) are influencing sales
out010_019_info = out010_019_data[['Outlet_Identifier', 'Outlet_Establishment_Year', 'Outlet_Type', 'Item_Weight', 'Item_MRP']]
print(out010_019_info)
# Out:
#      Outlet_Identifier  Item_Outlet_Sales              Item_Type  \
# 3               OUT010           732.3800  Fruits and Vegetables
# 23              OUT019           214.3876           Baking Goods
# 28              OUT010           178.4344                  Dairy
# 29              OUT019           125.8362                 Canned
# 30              OUT010           163.7868                  Dairy
# ...                ...                ...                    ...
# 8473            OUT010           431.4384            Hard Drinks
# 8480            OUT019           459.4020            Snack Foods
# 8486            OUT010            45.2744  Fruits and Vegetables
# 8490            OUT019           487.3656  Fruits and Vegetables
# 8509            OUT010           424.7804  Fruits and Vegetables
#
#         Outlet_Type  Item_Weight  Item_MRP
# 3     Grocery Store       19.200  182.0950
# 23    Grocery Store          NaN  107.6938
# 28    Grocery Store        5.925   45.5086
# ...

# %%
# Step 1: Calculate average sales for each store size (Medium, Small, Large)
average_sales_by_size = df.groupby('Outlet_Size')['Item_Outlet_Sales'].mean()

# Step 2: Print the average sales for each store size
print(average_sales_by_size)

# Step 3: Compare sales visually
plt.figure(figsize=(10, 6))
sns.boxplot(x='Outlet_Size', y='Item_Outlet_Sales', data=df, palette='Set2')
plt.title("Sales Distribution by Store Size")
plt.xlabel("Store Size")
plt.ylabel("Item Outlet Sales")
plt.tight_layout()
plt.show()

# Step 4: Check if medium stores have higher average sales than others
# Check if 'Large' and 'Small' keys exist before accessing them
if 'Medium' in average_sales_by_size.index and 'Small' in average_sales_by_size.index and 'Large' in average_sales_by_size.index:
    if average_sales_by_size['Medium'] > average_sales_by_size['Small'] and average_sales_by_size['Medium'] > average_sales_by_size['Large']:
        print("Yes, medium-sized stores have higher sales than others.")
    else:
        print("No, medium-sized stores do not have higher sales than others.")
else:
    print("Missing store size categories in the data.") # Handle cases where 'Large' or 'Small' are missing
# Out:
# Outlet_Size
# High      2298.995256
# Medium    2681.603542
# Small     1912.149161
# Name: Item_Outlet_Sales, dtype: float64
# <ipython-input-28-6f44a8ed6179>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Outlet_Size', y='Item_Outlet_Sales', data=df, palette='Set2')
# Missing store size categories in the data.

# %%
# Group by Outlet_Type and Outlet_Size, then calculate the mean Item_Outlet_Sales
grouped_sales = df.groupby(['Outlet_Type', 'Outlet_Size'])['Item_Outlet_Sales'].mean().reset_index()

# Sort to find the maximum
max_sales = grouped_sales.sort_values(by='Item_Outlet_Sales', ascending=False)

print(max_sales)
# Out:
#           Outlet_Type Outlet_Size  Item_Outlet_Sales
# 10  Supermarket Type3      Medium        3694.038558
# 5   Supermarket Type1       Small        2358.343066
# 4   Supermarket Type1      Medium        2348.354635
# 3   Supermarket Type1        High        2298.995256
# 7   Supermarket Type2      Medium        1995.498739
# 2       Grocery Store       Small         340.329723
# 0       Grocery Store        High                NaN
# 1       Grocery Store      Medium                NaN
# 6   Supermarket Type2        High                NaN
# 8   Supermarket Type2       Small                NaN
# 9   Supermarket Type3        High                NaN
# 11  Supermarket Type3       Small                NaN
# <ipython-input-29-a73a4acb71db>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# ...

# %%
# Step 1: Calculate the correlation matrix for numerical features
# Select only numerical columns before calculating correlation
numerical_df = df.select_dtypes(include=np.number)  # Filter for numeric columns only
correlation_matrix = numerical_df.corr()

# Step 2: Visualize the correlation matrix using a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Matrix")
plt.tight_layout()
plt.show()

# Step 3: Check the correlation of 'Item_Outlet_Sales' with other features
correlation_with_sales = correlation_matrix['Item_Outlet_Sales'].sort_values(ascending=False)
print("Correlation of features with Item_Outlet_Sales:")
print(correlation_with_sales)

# Step 4: Identify the most important feature (highest correlation)
most_important_feature = correlation_with_sales.index[1]  # Skip 'Item_Outlet_Sales' itself
print(f"The most important feature related to Item_Outlet_Sales is: {most_important_feature}")
# Out:
# Correlation of features with Item_Outlet_Sales:
# Item_Outlet_Sales    1.000000
# Item_MRP             0.567574
# Item_Weight          0.014123
# Item_Visibility     -0.128625
# Name: Item_Outlet_Sales, dtype: float64
# The most important feature related to Item_Outlet_Sales is: Item_MRP

# %% [markdown]
# # Data Cleansing
#
#
#
# 1.   Analyzing Unique Values
# 2.   Converting Non-Standard Data into Standard Data
# 3.   Remove Duplicates
# 4.   Identifying Missing Values & Fixing It
# 5.   What are Outliers? How can we Analyze and remove them

# %% [markdown]
# 1. Analyzing Unique Values

# %%
df.nunique()
# Out:
# Item_Identifier              1559
# Item_Weight                   415
# Item_Fat_Content                5
# Item_Visibility              7880
# Item_Type                      16
# Item_MRP                     5938
# Outlet_Identifier              10
# Outlet_Establishment_Year       9
# Outlet_Size                     3
# Outlet_Location_Type            3
# Outlet_Type                     4
# Item_Outlet_Sales            3493
# dtype: int64

# %%
df['Item_Fat_Content'].unique()
# Out:
# ['Low Fat', 'Regular', 'low fat', 'LF', 'reg']
# Categories (5, object): ['LF', 'Low Fat', 'Regular', 'low fat', 'reg']

# %%
df['Item_Fat_Content'].replace({'low fat': 'Low Fat', 'LF' : 'Low Fat', 'reg' : 'Regular'})
# Out:
# <ipython-input-33-2f52d8bab3db>:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df['Item_Fat_Content'].replace({'low fat': 'Low Fat', 'LF' : 'Low Fat', 'reg' : 'Regular'})
# 0       Low Fat
# 1       Regular
# 2       Low Fat
# 3       Regular
# 4       Low Fat
#          ...
# 8518    Low Fat
# 8519    Regular
# 8520    Low Fat
# 8521    Regular
# 8522    Low Fat
# Name: Item_Fat_Content, Length: 8523, dtype: category
# Categories (2, object): ['Low Fat', 'Regular']

# %%
df['Item_Fat_Content']= df['Item_Fat_Content'].replace({'low fat': 'Low Fat', 'LF' : 'Low Fat', 'reg' : 'Regular'})
# Out:
# <ipython-input-34-9399c92f0ec3>:1: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df['Item_Fat_Content']= df['Item_Fat_Content'].replace({'low fat': 'Low Fat', 'LF' : 'Low Fat', 'reg' : 'Regular'})

# %%
df['Item_Fat_Content'].unique()
# Out:
# ['Low Fat', 'Regular']
# Categories (2, object): ['Low Fat', 'Regular']

# %%
df['Outlet_Location_Type'].unique()
# Out:
# array(['Tier 1', 'Tier 3', 'Tier 2'], dtype=object)

# %%
df['Outlet_Type'].unique()
# Out:
# ['Supermarket Type1', 'Supermarket Type2', 'Grocery Store', 'Supermarket Type3']
# Categories (4, object): ['Grocery Store', 'Supermarket Type1', 'Supermarket Type2',
#                          'Supermarket Type3']

# %% [markdown]
# Data Cleaning : Duplicates

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8518    False
# 8519    False
# 8520    False
# 8521    False
# 8522    False
# Length: 8523, dtype: bool

# %%
df[df.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %%
df[df['Item_Identifier']=='DRG01']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 544            DRG01         14.8          Low Fat         0.044870
# 1218           DRG01         14.8          Low Fat         0.044841
# 3005           DRG01          NaN          Low Fat         0.044661
# 5974           DRG01          NaN          Low Fat         0.078576
# 8522           DRG01         14.8          Low Fat         0.044878
#
#         Item_Type  Item_MRP Outlet_Identifier Outlet_Establishment_Year  \
# 544   Soft Drinks    76.467            OUT035                      2004
# 1218  Soft Drinks    78.367            OUT013                      1987
# 3005  Soft Drinks    74.767            OUT027                      1985
# 5974  Soft Drinks    78.467            OUT019                      1985
# 8522  Soft Drinks    75.467            OUT046                      1997
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
df[df['Item_Identifier']=='FDS36']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 4986           FDS36         8.38          Regular         0.046878
# 5570           FDS36         8.38          Regular         0.046848
# 5666           FDS36         8.38          Regular         0.046887
# 6299           FDS36         8.38          Regular         0.046960
# 8279           FDS36         8.38          Regular         0.047153
# 8519           FDS36         8.38          Regular         0.046982
#
#          Item_Type  Item_MRP Outlet_Identifier Outlet_Establishment_Year  \
# 4986  Baking Goods   109.857            OUT035                      2004
# 5570  Baking Goods   110.557            OUT013                      1987
# 5666  Baking Goods   107.957            OUT046                      1997
# 6299  Baking Goods   111.857            OUT049                      1999
# 8279  Baking Goods   110.157            OUT017                      2007
# ...

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# Missing Values

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      1999      Medium               Tier 1
# 1                      2009      Medium               Tier 3
# 2                      1999      Medium               Tier 1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   category
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   object
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   category
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: category(2), float64(4), object(6)
# memory usage: 683.0+ KB

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
len(df)
# Out:
# 8523

# %%
df.isnull().sum()/len(df)*100
# Out:
# Item_Identifier               0.000000
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.276428
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %%
df.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 3           FDX07       19.200          Regular         0.000000
# 4           NCD19        8.930          Low Fat         0.000000
# 5           FDP36       10.395          Regular         0.000000
# 6           FDO10       13.650          Regular         0.012741
# 7           FDP10          NaN          Low Fat         0.127470
# 8           FDH17       16.200          Regular         0.016687
# 9           FDU28       19.200          Regular         0.094450
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# ...

# %%
# Select only numerical features for correlation calculation
numerical_df = df.select_dtypes(include=np.number) #Filter for numeric columns only

# Calculate the correlation matrix
correlation_matrix = numerical_df.corr()

# Display the correlation matrix using a heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title("Correlation Matrix")
plt.show()

# %%
df['Item_Weight'].mean()
# Out:
# np.float64(12.857645184135976)

# %%
df['Item_Weight'].median() # use in case of outliers
# Out:
# 12.6

# %%
df['rowno'] = np.arange(len(df))

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      1999      Medium               Tier 1
# 1                      2009      Medium               Tier 3
# 2                      1999      Medium               Tier 1
# ...

# %%
df_sub = df.filter(['Item_Weight','Item_MRP','Item_Outlet_Sales','rowno'])

# %%
df_sub.head()
# Out:
#    Item_Weight  Item_MRP  Item_Outlet_Sales  rowno
# 0         9.30  249.8092          3735.1380      0
# 1         5.92   48.2692           443.4228      1
# 2        17.50  141.6180          2097.2700      2
# 3        19.20  182.0950           732.3800      3
# 4         8.93   53.8614           994.7052      4

# %%
import statsmodels as sm
from statsmodels.imputation import mice

# %%
df_m = mice.MICEData(df_sub)

# %%
df_m.update_all(50)

# %%
df_m

# %%
x = df_m.data

# %%
x.head(10)
# Out:
#    Item_Weight  Item_MRP  Item_Outlet_Sales  rowno
# 0        9.300  249.8092          3735.1380      0
# 1        5.920   48.2692           443.4228      1
# 2       17.500  141.6180          2097.2700      2
# 3       19.200  182.0950           732.3800      3
# 4        8.930   53.8614           994.7052      4
# 5       10.395   51.4008           556.6088      5
# 6       13.650   57.6588           343.5528      6
# 7       13.350  107.7622          4022.7636      7
# 8       16.200   96.9726          1076.5986      8
# 9       19.200  187.8214          4710.5350      9

# %%
df['Item_Weight'].plot.hist()
df_m.plot_imputed_hist('Item_Weight')
plt.show()

# %%
df.loc[df.rowno.isin(x.rowno),'Item_Weight'] = x.Item_Weight

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   category
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   object
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   category
#  11  Item_Outlet_Sales          8523 non-null   float64
#  12  rowno                      8523 non-null   int64
# ...

# %% [markdown]
# Outliers

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      1999      Medium               Tier 1
# 1                      2009      Medium               Tier 3
# 2                      1999      Medium               Tier 1
# ...

# %%
sns.boxplot(df['Item_Outlet_Sales'])
# Out:
# <Axes: ylabel='Item_Outlet_Sales'>

# %%
from scipy import stats

# %%
z = np.abs(stats.zscore(df['Item_Outlet_Sales']))
z
# Out:
# array([0.910601  , 1.01844035, 0.04923754, ..., 0.57909963, 0.19672492,
#        0.82959407])

# %%
threshold = 3

# %%
outliers=np.where(z>threshold)

# %%
o=outliers[0]

# %%
o
# Out:
# array([ 130,  145,  276,  304,  333,  373,  456,  472,  661,  694,  753,
#         809,  935,  991,  997, 1009, 1138, 1254, 1450, 1506, 1859, 1998,
#        2109, 2216, 2238, 2293, 2516, 2535, 2776, 3083, 3087, 3098, 3154,
#        3234, 3286, 3407, 3667, 3709, 3720, 3757, 4289, 4346, 4349, 4676,
#        4681, 4772, 4888, 4961, 4991, 5065, 5177, 5185, 5223, 5315, 5500,
#        5550, 5619, 5752, 5799, 5812, 5977, 6000, 6134, 6334, 6409, 6537,
#        6541, 6606, 6886, 6993, 7016, 7076, 7188, 7191, 7236, 7256, 7302,
#        7343, 7560, 7562, 7609, 7690, 7752, 7816, 7826, 7930, 8039, 8201,
#        8245, 8447])

# %%
z[8245]
# Out:
# np.float64(3.145932287343738)

# %%
z[130]
# Out:
# np.float64(3.3913544171949606)

# %%
o
# Out:
# array([ 130,  145,  276,  304,  333,  373,  456,  472,  661,  694,  753,
#         809,  935,  991,  997, 1009, 1138, 1254, 1450, 1506, 1859, 1998,
#        2109, 2216, 2238, 2293, 2516, 2535, 2776, 3083, 3087, 3098, 3154,
#        3234, 3286, 3407, 3667, 3709, 3720, 3757, 4289, 4346, 4349, 4676,
#        4681, 4772, 4888, 4961, 4991, 5065, 5177, 5185, 5223, 5315, 5500,
#        5550, 5619, 5752, 5799, 5812, 5977, 6000, 6134, 6334, 6409, 6537,
#        6541, 6606, 6886, 6993, 7016, 7076, 7188, 7191, 7236, 7256, 7302,
#        7343, 7560, 7562, 7609, 7690, 7752, 7816, 7826, 7930, 8039, 8201,
#        8245, 8447])

# %%
len(o)
# Out:
# 90

# %% [markdown]
# Treatment of Outliers

# %%
o
# Out:
# array([ 130,  145,  276,  304,  333,  373,  456,  472,  661,  694,  753,
#         809,  935,  991,  997, 1009, 1138, 1254, 1450, 1506, 1859, 1998,
#        2109, 2216, 2238, 2293, 2516, 2535, 2776, 3083, 3087, 3098, 3154,
#        3234, 3286, 3407, 3667, 3709, 3720, 3757, 4289, 4346, 4349, 4676,
#        4681, 4772, 4888, 4961, 4991, 5065, 5177, 5185, 5223, 5315, 5500,
#        5550, 5619, 5752, 5799, 5812, 5977, 6000, 6134, 6334, 6409, 6537,
#        6541, 6606, 6886, 6993, 7016, 7076, 7188, 7191, 7236, 7256, 7302,
#        7343, 7560, 7562, 7609, 7690, 7752, 7816, 7826, 7930, 8039, 8201,
#        8245, 8447])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   category
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   object
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   category
#  11  Item_Outlet_Sales          8523 non-null   float64
#  12  rowno                      8523 non-null   int64
# ...

# %%
df_copy = df.copy()

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   category
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   object
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   category
#  11  Item_Outlet_Sales          8523 non-null   float64
#  12  rowno                      8523 non-null   int64
# ...

# %%
o
# Out:
# array([ 130,  145,  276,  304,  333,  373,  456,  472,  661,  694,  753,
#         809,  935,  991,  997, 1009, 1138, 1254, 1450, 1506, 1859, 1998,
#        2109, 2216, 2238, 2293, 2516, 2535, 2776, 3083, 3087, 3098, 3154,
#        3234, 3286, 3407, 3667, 3709, 3720, 3757, 4289, 4346, 4349, 4676,
#        4681, 4772, 4888, 4961, 4991, 5065, 5177, 5185, 5223, 5315, 5500,
#        5550, 5619, 5752, 5799, 5812, 5977, 6000, 6134, 6334, 6409, 6537,
#        6541, 6606, 6886, 6993, 7016, 7076, 7188, 7191, 7236, 7256, 7302,
#        7343, 7560, 7562, 7609, 7690, 7752, 7816, 7826, 7930, 8039, 8201,
#        8245, 8447])

# %%
for i in o :
  df.drop(df[df.rowno==i].index, inplace=True)

# %%
sns.boxplot(x=df_copy['Item_Outlet_Sales'])
# Out:
# <Axes: xlabel='Item_Outlet_Sales'>

# %%
sns.boxplot(x=df['Item_Outlet_Sales'])
# Out:
# <Axes: xlabel='Item_Outlet_Sales'>

# %%
df['Item_Outlet_Sales'].max()
# Out:
# 7298.4996

# %% [markdown]
# # Data Transformation
#
#
# 1.   Spliting
# 2.   Merging
# 3.   Grouping & Analytical function
# 4.   Filter - Column/Rows

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      1999      Medium               Tier 1
# 1                      2009      Medium               Tier 3
# 2                      1999      Medium               Tier 1
# ...

# %%
df_items=df.filter(['rowno','Item_Identifier','Item_Weight','Item_Fat_Content','Item_Visibility','Item_Type','Item_MRP'])

# %%
df_items.head()
# Out:
#    rowno Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0      0           FDA15         9.30          Low Fat         0.016047
# 1      1           DRC01         5.92          Regular         0.019278
# 2      2           FDN15        17.50          Low Fat         0.016760
# 3      3           FDX07        19.20          Regular         0.000000
# 4      4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP
# 0                  Dairy  249.8092
# 1            Soft Drinks   48.2692
# 2                   Meat  141.6180
# 3  Fruits and Vegetables  182.0950
# 4              Household   53.8614

# %%
df_outlets=df.filter(['rowno','Outlet_Identifier','Outlet_Establishment_Year','Outlet_Size','Outlet_Location_Type','Outlet_Type','Item_Outlet_Sales'])

# %%
df_outlets.head()
# Out:
#    rowno Outlet_Identifier Outlet_Establishment_Year Outlet_Size  \
# 0      0            OUT049                      1999      Medium
# 1      1            OUT018                      2009      Medium
# 2      2            OUT049                      1999      Medium
# 3      3            OUT010                      1998         NaN
# 4      4            OUT013                      1987        High
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228
# 2               Tier 1  Supermarket Type1          2097.2700
# 3               Tier 3      Grocery Store           732.3800
# 4               Tier 3  Supermarket Type1           994.7052

# %% [markdown]
# # 1. Spliting

# %%
df.iloc[:,[12,0,1,2,3,4,5,11]]
# Out:
#       rowno Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0         0           FDA15        9.300          Low Fat         0.016047
# 1         1           DRC01        5.920          Regular         0.019278
# 2         2           FDN15       17.500          Low Fat         0.016760
# 3         3           FDX07       19.200          Regular         0.000000
# 4         4           NCD19        8.930          Low Fat         0.000000
# ...     ...             ...          ...              ...              ...
# 8518   8518           FDF22        6.865          Low Fat         0.056783
# 8519   8519           FDS36        8.380          Regular         0.046982
# 8520   8520           NCJ29       10.600          Low Fat         0.035186
# 8521   8521           FDN46        7.210          Regular         0.145221
# 8522   8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP  Item_Outlet_Sales
# ...

# %%
df.iloc[:,[12,6,7,8,9,10,11]]
# Out:
#       rowno Outlet_Identifier Outlet_Establishment_Year Outlet_Size  \
# 0         0            OUT049                      1999      Medium
# 1         1            OUT018                      2009      Medium
# 2         2            OUT049                      1999      Medium
# 3         3            OUT010                      1998         NaN
# 4         4            OUT013                      1987        High
# ...     ...               ...                       ...         ...
# 8518   8518            OUT013                      1987        High
# 8519   8519            OUT045                      2002         NaN
# 8520   8520            OUT035                      2004       Small
# 8521   8521            OUT018                      2009      Medium
# 8522   8522            OUT046                      1997       Small
#
#      Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0                  Tier 1  Supermarket Type1          3735.1380
# ...

# %%
# prompt: Problem statement
# In the Big mart dataset, you have separated the information for Items and outlets. Now your task is to find the correlation between Item_Outlet_Sales and all other features of the split_items dataset.
# Your task is to split the big mart dataset based on Items and Outlet information as discussed in the video. Then find the feature having a correlation greater than 0.5 in the split_items dataset with the feature Item_Outlet_Sales.
# Expected Output
# Print the feature with a correlation greater than 0.5 with Item_Outlet_Sales in the split_items dataset.

# Assuming df_items and df_outlets are already created as in the provided code.

# Merge the two DataFrames on 'rowno' to have all relevant columns together
merged_df = pd.merge(df_items, df_outlets, on='rowno')

# Calculate the correlation matrix for the numerical features in the merged DataFrame
numerical_merged_df = merged_df.select_dtypes(include=np.number)
correlation_matrix_merged = numerical_merged_df.corr()

# Get the correlation of 'Item_Outlet_Sales' with other features in the merged DataFrame
correlation_with_sales = correlation_matrix_merged['Item_Outlet_Sales']

# Find features with correlation greater than 0.5
features_above_threshold = correlation_with_sales[abs(correlation_with_sales) > 0.5]

# Print the features
print(features_above_threshold)
# Out:
# Item_MRP             0.563164
# Item_Outlet_Sales    1.000000
# Name: Item_Outlet_Sales, dtype: float64

# %% [markdown]
# # 2. Merging

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      1999      Medium               Tier 1
# 1                      2009      Medium               Tier 3
# 2                      1999      Medium               Tier 1
# ...

# %%
df_items.head()
# Out:
#    rowno Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0      0           FDA15         9.30          Low Fat         0.016047
# 1      1           DRC01         5.92          Regular         0.019278
# 2      2           FDN15        17.50          Low Fat         0.016760
# 3      3           FDX07        19.20          Regular         0.000000
# 4      4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP
# 0                  Dairy  249.8092
# 1            Soft Drinks   48.2692
# 2                   Meat  141.6180
# 3  Fruits and Vegetables  182.0950
# 4              Household   53.8614

# %%
df_outlets.head()
# Out:
#    rowno Outlet_Identifier Outlet_Establishment_Year Outlet_Size  \
# 0      0            OUT049                      1999      Medium
# 1      1            OUT018                      2009      Medium
# 2      2            OUT049                      1999      Medium
# 3      3            OUT010                      1998         NaN
# 4      4            OUT013                      1987        High
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 0               Tier 1  Supermarket Type1          3735.1380
# 1               Tier 3  Supermarket Type2           443.4228
# 2               Tier 1  Supermarket Type1          2097.2700
# 3               Tier 3      Grocery Store           732.3800
# 4               Tier 3  Supermarket Type1           994.7052

# %%
pd.merge(df_items,df_outlets,on='rowno', how='inner')
# Out:
#       rowno Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0         0           FDA15        9.300          Low Fat         0.016047
# 1         1           DRC01        5.920          Regular         0.019278
# 2         2           FDN15       17.500          Low Fat         0.016760
# 3         3           FDX07       19.200          Regular         0.000000
# 4         4           NCD19        8.930          Low Fat         0.000000
# ...     ...             ...          ...              ...              ...
# 8428   8518           FDF22        6.865          Low Fat         0.056783
# 8429   8519           FDS36        8.380          Regular         0.046982
# 8430   8520           NCJ29       10.600          Low Fat         0.035186
# 8431   8521           FDN46        7.210          Regular         0.145221
# 8432   8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# ...

# %% [markdown]
# # 3. Grouping

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      1999      Medium               Tier 1
# 1                      2009      Medium               Tier 3
# 2                      1999      Medium               Tier 1
# ...

# %%
df.groupby('Outlet_Type').count()
# Out:
# <ipython-input-99-f6fb24c56d6e>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Outlet_Type').count()
#                    Item_Identifier  Item_Weight  Item_Fat_Content  \
# Outlet_Type
# Grocery Store                 1083         1083              1083
# Supermarket Type1             5547         5547              5547
# Supermarket Type2              928          928               928
# Supermarket Type3              875          875               875
#
#                    Item_Visibility  Item_Type  Item_MRP  Outlet_Identifier  \
# Outlet_Type
# Grocery Store                 1083       1083      1083               1083
# Supermarket Type1             5547       5547      5547               5547
# Supermarket Type2              928        928       928                928
# ...

# %%
df.groupby('Outlet_Type').agg({'Item_Outlet_Sales':'sum'})
# Out:
# <ipython-input-100-5e52502ade8c>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Outlet_Type').agg({'Item_Outlet_Sales':'sum'})
#                    Item_Outlet_Sales
# Outlet_Type
# Grocery Store           3.680343e+05
# Supermarket Type1       1.267026e+07
# Supermarket Type2       1.851823e+06
# Supermarket Type3       2.939746e+06

# %%
df.groupby(['Outlet_Type','Outlet_Location_Type']).agg({'Item_Outlet_Sales':'sum'})
# Out:
# <ipython-input-101-831bcc6b1480>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Outlet_Type','Outlet_Location_Type']).agg({'Item_Outlet_Sales':'sum'})
#                                         Item_Outlet_Sales
# Outlet_Type       Outlet_Location_Type
# Grocery Store     Tier 1                     1.796941e+05
#                   Tier 2                     0.000000e+00
#                   Tier 3                     1.883402e+05
# Supermarket Type1 Tier 1                     4.237954e+06
#                   Tier 2                     6.331592e+06
#                   Tier 3                     2.100719e+06
# Supermarket Type2 Tier 1                     0.000000e+00
#                   Tier 2                     0.000000e+00
# ...

# %%
df.groupby(['Outlet_Type','Outlet_Size']).agg({'Item_Outlet_Sales':np.sum})
# Out:
# <ipython-input-102-48c8ba400b11>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Outlet_Type','Outlet_Size']).agg({'Item_Outlet_Sales':np.sum})
# <ipython-input-102-48c8ba400b11>:1: FutureWarning: The provided callable <function sum at 0x7cd6e2a08f40> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   df.groupby(['Outlet_Type','Outlet_Size']).agg({'Item_Outlet_Sales':np.sum})
#                                Item_Outlet_Sales
# Outlet_Type       Outlet_Size
# Grocery Store     High              0.000000e+00
#                   Medium            0.000000e+00
#                   Small             1.796941e+05
# Supermarket Type1 High              2.100719e+06
# ...

# %%
df.groupby(['Outlet_Type','Outlet_Size']).agg({'Item_Outlet_Sales':np.mean})
# Out:
# <ipython-input-103-62b145db304d>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Outlet_Type','Outlet_Size']).agg({'Item_Outlet_Sales':np.mean})
# <ipython-input-103-62b145db304d>:1: FutureWarning: The provided callable <function mean at 0x7cd6e2a0a020> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df.groupby(['Outlet_Type','Outlet_Size']).agg({'Item_Outlet_Sales':np.mean})
#                                Item_Outlet_Sales
# Outlet_Type       Outlet_Size
# Grocery Store     High                       NaN
#                   Medium                     NaN
#                   Small               340.329723
# ...

# %%
df.groupby(['Outlet_Type','Outlet_Size']).agg({'Item_Outlet_Sales':np.max})
# Out:
# <ipython-input-104-4a4ba9cbdd61>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(['Outlet_Type','Outlet_Size']).agg({'Item_Outlet_Sales':np.max})
# <ipython-input-104-4a4ba9cbdd61>:1: FutureWarning: The provided callable <function max at 0x7cd6e2a09620> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby(['Outlet_Type','Outlet_Size']).agg({'Item_Outlet_Sales':np.max})
#                                Item_Outlet_Sales
# Outlet_Type       Outlet_Size
# Grocery Store     High                       NaN
#                   Medium                     NaN
#                   Small                1482.0708
# Supermarket Type1 High                 7105.4176
# ...

# %%
# prompt: Problem statement
# For the big mart dataset, your manager wants to make a decision on opening a new outlet, she gave you the task to provide her with the data grouped by the location of the previously opened outlets and the type of outlet and find out the average itemoutletsales for each of these groups.
# Note:
# Use the reset_index() function after grouping the data to convert the grouped columns back into regular columns for easier manipulation.
# Expected output
# Print the highest sum of sales based on the "Outlet Type" and the "Outlet Location Type".
# Convert the output to the integer type having a floor value.

# Group the data by 'Outlet_Type' and 'Outlet_Location_Type' and calculate the mean of 'Item_Outlet_Sales'
grouped_sales = df.groupby(['Outlet_Type', 'Outlet_Location_Type'])['Item_Outlet_Sales'].mean().reset_index()

# Find the row with the highest 'Item_Outlet_Sales'
highest_sales_row = grouped_sales.loc[grouped_sales['Item_Outlet_Sales'].idxmax()]

# Extract the values from the row
outlet_type = highest_sales_row['Outlet_Type']
outlet_location_type = highest_sales_row['Outlet_Location_Type']
average_sales = highest_sales_row['Item_Outlet_Sales']

# Convert the average sales to an integer with a floor value
average_sales_int = int(average_sales)


print(f"Outlet Type: {outlet_type}")
print(f"Outlet Location Type: {outlet_location_type}")
print(f"Highest Average Item Outlet Sales: {average_sales_int}")
# Out:
# Outlet Type: Supermarket Type3
# Outlet Location Type: Tier 3
# Highest Average Item Outlet Sales: 3359
# <ipython-input-105-fd043fbb5285>:10: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_sales = df.groupby(['Outlet_Type', 'Outlet_Location_Type'])['Item_Outlet_Sales'].mean().reset_index()

# %% [markdown]
# # 4. Filtering

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      1999      Medium               Tier 1
# 1                      2009      Medium               Tier 3
# 2                      1999      Medium               Tier 1
# ...

# %%
df[df['Outlet_Location_Type']=='Tier 1']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.30          Low Fat         0.016047
# 2              FDN15        17.50          Low Fat         0.016760
# 10             FDY07        11.80          Low Fat         0.000000
# 11             FDA03        18.50          Regular         0.045464
# 12             FDX32        15.10          Regular         0.100014
# ...              ...          ...              ...              ...
# 8480           FDQ58         8.18          Low Fat         0.000000
# 8490           FDU44        11.00          Regular         0.102296
# 8492           FDT34         9.30          Low Fat         0.174350
# 8517           FDF53        20.75          Regular         0.083607
# 8522           DRG01        14.80          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df[(df['Outlet_Location_Type']=='Tier 1') & (df['Outlet_Size']== 'Medium')]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 2              FDN15       17.500          Low Fat         0.016760
# 10             FDY07       11.800          Low Fat         0.000000
# 12             FDX32       15.100          Regular         0.100014
# 17             FDP49        9.000          Regular         0.069196
# ...              ...          ...              ...              ...
# 8451           FDK21        7.905          Low Fat         0.010028
# 8467           FDV31        9.800          Low Fat         0.000000
# 8470           FDW27        5.860          Regular         0.151088
# 8475           NCS17       18.600          Low Fat         0.080627
# 8479           FDL10        8.395          Low Fat         0.039554
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
df_filter=df[(df['Outlet_Location_Type']=='Tier 1') | (df['Outlet_Size']== 'Medium')]

# %%
df_filter.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat         0.016047
# 1           DRC01        5.920          Regular         0.019278
# 2           FDN15       17.500          Low Fat         0.016760
# 5           FDP36       10.395          Regular         0.000000
# 7           FDP10       13.350          Low Fat         0.127470
#
#       Item_Type  Item_MRP Outlet_Identifier Outlet_Establishment_Year  \
# 0         Dairy  249.8092            OUT049                      1999
# 1   Soft Drinks   48.2692            OUT018                      2009
# 2          Meat  141.6180            OUT049                      1999
# 5  Baking Goods   51.4008            OUT018                      2009
# 7   Snack Foods  107.7622            OUT027                      1985
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  \
# 0      Medium               Tier 1  Supermarket Type1          3735.1380
# ...

# %% [markdown]
# # Feature Scaling : Normalization

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      1999      Medium               Tier 1
# 1                      2009      Medium               Tier 3
# 2                      1999      Medium               Tier 1
# ...

# %%
df.Item_MRP.describe()
# Out:
# count    8433.000000
# mean      140.101789
# std        61.916404
# min        31.290000
# 25%        93.377800
# 50%       142.015400
# 75%       184.760800
# max       266.888400
# Name: Item_MRP, dtype: float64

# %%
df.Item_Weight.describe()
# Out:
# count    8433.000000
# mean       12.849271
# std         4.648933
# min         4.555000
# 25%         8.760000
# 50%        12.600000
# 75%        16.850000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df2=df.copy()

# %%
dfnorm = df2.filter(['Item_MRP','Item_Weight'])

# %%
dfnorm.head()
# Out:
#    Item_MRP  Item_Weight
# 0  249.8092         9.30
# 1   48.2692         5.92
# 2  141.6180        17.50
# 3  182.0950        19.20
# 4   53.8614         8.93

# %%
norm = MinMaxScaler().fit(dfnorm)

# %%
dfnorm1=norm.transform(dfnorm)

# %%
dfnorm1
# Out:
# array([[0.92750715, 0.28252456],
#        [0.0720684 , 0.08127419],
#        [0.46828841, 0.77076511],
#        ...,
#        [0.22849221, 0.35992855],
#        [0.30493925, 0.15808276],
#        [0.18750976, 0.61000298]])

# %%
rownoarr=df2[['rowno']].to_numpy()

# %%
rownoarr
# Out:
# array([[   0],
#        [   1],
#        [   2],
#        ...,
#        [8520],
#        [8521],
#        [8522]])

# %%
dfnorm2 = pd.DataFrame(np.append(dfnorm1,rownoarr,axis=1), columns=['Item_MRP','Item_Weight','rowno'])

# %%
dfnorm2.head()
# Out:
#    Item_MRP  Item_Weight  rowno
# 0  0.927507     0.282525    0.0
# 1  0.072068     0.081274    1.0
# 2  0.468288     0.770765    2.0
# 3  0.640093     0.871986    3.0
# 4  0.095805     0.260494    4.0

# %%
dfnorm2.Item_Weight.describe()
# Out:
# count    8433.000000
# mean        0.493854
# std         0.276805
# min         0.000000
# 25%         0.250372
# 50%         0.479012
# 75%         0.732063
# max         1.000000
# Name: Item_Weight, dtype: float64

# %%
# prompt: drop the item_weight and item mrp from df2 before merging with dfnorm2

# Drop 'Item_Weight' and 'Item_MRP' from df2 before merging
df2 = df2.drop(['Item_Weight', 'Item_MRP'], axis=1)

# Merge df2 with dfnorm2
merged_df = pd.merge(df2, dfnorm2, on='rowno', how='inner')

# %%
merged_df.head()
# Out:
#   Item_Identifier Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           FDA15          Low Fat         0.016047                  Dairy
# 1           DRC01          Regular         0.019278            Soft Drinks
# 2           FDN15          Low Fat         0.016760                   Meat
# 3           FDX07          Regular         0.000000  Fruits and Vegetables
# 4           NCD19          Low Fat         0.000000              Household
#
#   Outlet_Identifier Outlet_Establishment_Year Outlet_Size  \
# 0            OUT049                      1999      Medium
# 1            OUT018                      2009      Medium
# 2            OUT049                      1999      Medium
# 3            OUT010                      1998         NaN
# 4            OUT013                      1987        High
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales  rowno  Item_MRP  \
# 0               Tier 1  Supermarket Type1          3735.1380      0  0.927507
# ...

# %% [markdown]
# # Feature Scaling : Standardization

# %% [markdown]
# mean = 0 & std dev = 1

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      1999      Medium               Tier 1
# 1                      2009      Medium               Tier 3
# 2                      1999      Medium               Tier 1
# ...

# %%
df_stddev=df.copy()

# %%
from sklearn.preprocessing import StandardScaler

# %%
ncols = ['Item_Weight','Item_MRP']

# %%
for i in ncols:
  std = StandardScaler().fit(df_stddev[[i]])
  df_stddev[i] = std.transform(df_stddev[[i]])

# %%
df_stddev.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15    -0.763505          Low Fat         0.016047
# 1           DRC01    -1.490596          Regular         0.019278
# 2           FDN15     1.000446          Low Fat         0.016760
# 3           FDX07     1.366143          Regular         0.000000
# 4           NCD19    -0.843098          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  1.771968            OUT049
# 1            Soft Drinks -1.483259            OUT018
# 2                   Meat  0.024489            OUT049
# 3  Fruits and Vegetables  0.678265            OUT010
# 4              Household -1.392935            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      1999      Medium               Tier 1
# 1                      2009      Medium               Tier 3
# 2                      1999      Medium               Tier 1
# ...

# %%
df_stddev.Item_Weight.describe()
# Out:
# count    8.433000e+03
# mean     2.312866e-16
# std      1.000059e+00
# min     -1.784230e+00
# 25%     -8.796672e-01
# 50%     -5.362222e-02
# 75%      8.606203e-01
# max      1.828642e+00
# Name: Item_Weight, dtype: float64

# %%
df.Item_Weight.describe()
# Out:
# count    8433.000000
# mean       12.849271
# std         4.648933
# min         4.555000
# 25%         8.760000
# 50%        12.600000
# 75%        16.850000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %% [markdown]
# # Feature Scaling : Method Comparisons

# %%
sns.kdeplot(df.Item_Weight)
plt.title('Original Item Weight')
plt.show()
sns.kdeplot(dfnorm2.Item_Weight) # Changed df3 to dfnorm2
plt.title('Normalized Item Weight')
plt.show()
sns.kdeplot(df_stddev.Item_Weight)
plt.title('Standardized Item Weight')
plt.show()

# %%
sns.boxplot(x=df.Item_MRP)
plt.title('Original Item MRP')
plt.show()
sns.boxplot(x=dfnorm2.Item_MRP)
plt.title('Normalized Item MRP')
plt.show()
sns.boxplot(x=df_stddev.Item_MRP)
plt.title('Standardized Item MRP')
plt.show()

# %% [markdown]
# # Feature Selection : Missing Value Ratio

# %%
df2=pd.read_csv('/content/drive/MyDrive/Analytics/bigmart.csv')

# %%
df2.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
o_cat = {'Meat':'Non-Veg'}
df2['Item_Category'] = df2['Item_Type'].map(o_cat)

# %%
df2.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df2.isnull().sum()/len(df2)*100
# Out:
# Item_Identifier               0.000000
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.276428
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# Item_Category                95.013493
# dtype: float64

# %%
df2.Item_Category.unique()
# Out:
# array([nan, 'Non-Veg'], dtype=object)

# %% [markdown]
# # Feature Selection : Low Variance

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      1999      Medium               Tier 1
# 1                      2009      Medium               Tier 3
# 2                      1999      Medium               Tier 1
# ...

# %%
df_check= df.filter(['Item_Weight','Item_Visibility','Item_MRP'])

# %%
df_check.var()
# Out:
# Item_Weight          21.612575
# Item_Visibility       0.002674
# Item_MRP           3833.641091
# dtype: float64

# %%
pd.options.display.float_format = '{:.5f}'.format

# %%
#Let us standardize dfrtpr
# numerical features
ncols = ['Item_Weight','Item_Visibility','Item_MRP']

# apply standardization on numerical features
for i in ncols:

    # fit on data columns
    scale = StandardScaler().fit(df_check[[i]])

    # transform the data
    df_check[i] = scale.transform(df_check[[i]])

# Check the variance now
#dfrtprn=dfrtpr.filter(["Item_Weight","Item_Visibility","Item_MRP"])
df_check.var()
# Out:
# Item_Weight       1.00012
# Item_Visibility   1.00012
# Item_MRP          1.00012
# dtype: float64

# %% [markdown]
# # Feature Selection : High Correlation Filter

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15      9.30000          Low Fat          0.01605
# 1           DRC01      5.92000          Regular          0.01928
# 2           FDN15     17.50000          Low Fat          0.01676
# 3           FDX07     19.20000          Regular          0.00000
# 4           NCD19      8.93000          Low Fat          0.00000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy 249.80920            OUT049
# 1            Soft Drinks  48.26920            OUT018
# 2                   Meat 141.61800            OUT049
# 3  Fruits and Vegetables 182.09500            OUT010
# 4              Household  53.86140            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      1999      Medium               Tier 1
# 1                      2009      Medium               Tier 3
# 2                      1999      Medium               Tier 1
# ...

# %%
df['Item_Delivery_Charges']=df.Item_MRP + (df.Item_MRP*0.02)

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15      9.30000          Low Fat          0.01605
# 1           DRC01      5.92000          Regular          0.01928
# 2           FDN15     17.50000          Low Fat          0.01676
# 3           FDX07     19.20000          Regular          0.00000
# 4           NCD19      8.93000          Low Fat          0.00000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy 249.80920            OUT049
# 1            Soft Drinks  48.26920            OUT018
# 2                   Meat 141.61800            OUT049
# 3  Fruits and Vegetables 182.09500            OUT010
# 4              Household  53.86140            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      1999      Medium               Tier 1
# 1                      2009      Medium               Tier 3
# 2                      1999      Medium               Tier 1
# ...

# %%
df_numeric = df.select_dtypes(include=['number'])
correlation_matrix = df_numeric.corr()
correlation_matrix
# Out:
#                        Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                1.00000         -0.00349   0.02116
# Item_Visibility           -0.00349          1.00000   0.00035
# Item_MRP                   0.02116          0.00035   1.00000
# Item_Outlet_Sales          0.00534         -0.13166   0.56316
# rowno                     -0.03264         -0.00172   0.00223
# Item_Delivery_Charges      0.02116          0.00035   1.00000
#
#                        Item_Outlet_Sales    rowno  Item_Delivery_Charges
# Item_Weight                      0.00534 -0.03264                0.02116
# Item_Visibility                 -0.13166 -0.00172                0.00035
# Item_MRP                         0.56316  0.00223                1.00000
# Item_Outlet_Sales                1.00000 -0.00818                0.56316
# rowno                           -0.00818  1.00000                0.00223
# Item_Delivery_Charges            0.56316  0.00223                1.00000

# %% [markdown]
# # Feature Selection : Backward Feature Selection

# %%
from sklearn.feature_selection import RFE

# %%
from sklearn.linear_model import LinearRegression

# %%
df_imputed = df.copy()

# %%
df_imputed.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15      9.30000          Low Fat          0.01605
# 1           DRC01      5.92000          Regular          0.01928
# 2           FDN15     17.50000          Low Fat          0.01676
# 3           FDX07     19.20000          Regular          0.00000
# 4           NCD19      8.93000          Low Fat          0.00000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy 249.80920            OUT049
# 1            Soft Drinks  48.26920            OUT018
# 2                   Meat 141.61800            OUT049
# 3  Fruits and Vegetables 182.09500            OUT010
# 4              Household  53.86140            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      1999      Medium               Tier 1
# 1                      2009      Medium               Tier 3
# 2                      1999      Medium               Tier 1
# ...

# %%
df_check=df_imputed.filter(['Item_Weight','Item_Visibility','Item_MRP'])

# %%
lre=LinearRegression()

# %%
rfe = RFE(estimator=lre, n_features_to_select=3, step=1)

# %%
rfe = rfe.fit(df_check,df_imputed.Item_Outlet_Sales)

# %%
rfe.ranking_
# Out:
# array([1, 1, 1])

# %%
rfe.support_
# Out:
# array([ True,  True,  True])

# %% [markdown]
# # Feature Selection : Forward Feature Selection

# %%
from sklearn.feature_selection import f_regression

# %%
df_check.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP
# 0      9.30000          0.01605 249.80920
# 1      5.92000          0.01928  48.26920
# 2     17.50000          0.01676 141.61800
# 3     19.20000          0.00000 182.09500
# 4      8.93000          0.00000  53.86140

# %%
df_imputed.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15      9.30000          Low Fat          0.01605
# 1           DRC01      5.92000          Regular          0.01928
# 2           FDN15     17.50000          Low Fat          0.01676
# 3           FDX07     19.20000          Regular          0.00000
# 4           NCD19      8.93000          Low Fat          0.00000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy 249.80920            OUT049
# 1            Soft Drinks  48.26920            OUT018
# 2                   Meat 141.61800            OUT049
# 3  Fruits and Vegetables 182.09500            OUT010
# 4              Household  53.86140            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      1999      Medium               Tier 1
# 1                      2009      Medium               Tier 3
# 2                      1999      Medium               Tier 1
# ...

# %%
fr = f_regression(df_check,df_imputed.Item_Outlet_Sales)

# %%
fr
# Out:
# (array([2.40587740e-01, 1.48714336e+02, 3.91584067e+03]),
#  array([6.23794705e-01, 6.38659602e-34, 0.00000000e+00]))

# %%
feature=[]

# %%
for i in range(0,len(df_check.columns)):
  if fr[1][i] <= 0.05:
    feature.append(df_check.columns[i])

# %%
feature
# Out:
# ['Item_Visibility', 'Item_MRP']

# %% [markdown]
# # Feature Creation

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15      9.30000          Low Fat          0.01605
# 1           DRC01      5.92000          Regular          0.01928
# 2           FDN15     17.50000          Low Fat          0.01676
# 3           FDX07     19.20000          Regular          0.00000
# 4           NCD19      8.93000          Low Fat          0.00000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy 249.80920            OUT049
# 1            Soft Drinks  48.26920            OUT018
# 2                   Meat 141.61800            OUT049
# 3  Fruits and Vegetables 182.09500            OUT010
# 4              Household  53.86140            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      1999      Medium               Tier 1
# 1                      2009      Medium               Tier 3
# 2                      1999      Medium               Tier 1
# ...

# %%
df.Item_MRP.unique()
# Out:
# array([249.8092,  48.2692, 141.618 , ...,  57.5904, 214.5218,  75.467 ])

# %%
x=df.Item_MRP.unique()

# %%
x.sort()
x
# Out:
# array([ 31.29  ,  31.49  ,  31.89  , ..., 266.5884, 266.6884, 266.8884])

# %%
pd.cut(x, bins=3, labels=['Low','Medium','High'])
# Out:
# ['Low', 'Low', 'Low', 'Low', 'Low', ..., 'High', 'High', 'High', 'High', 'High']
# Length: 5892
# Categories (3, object): ['Low' < 'Medium' < 'High']

# %%
df['Item_Value'] = pd.cut(df.Item_MRP, bins=3, labels=['Low','Medium','High'])

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15      9.30000          Low Fat          0.01605
# 1           DRC01      5.92000          Regular          0.01928
# 2           FDN15     17.50000          Low Fat          0.01676
# 3           FDX07     19.20000          Regular          0.00000
# 4           NCD19      8.93000          Low Fat          0.00000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy 249.80920            OUT049
# 1            Soft Drinks  48.26920            OUT018
# 2                   Meat 141.61800            OUT049
# 3  Fruits and Vegetables 182.09500            OUT010
# 4              Household  53.86140            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      1999      Medium               Tier 1
# 1                      2009      Medium               Tier 3
# 2                      1999      Medium               Tier 1
# ...

# %% [markdown]
# # EDA Summary & Finalized Dataset

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15      9.30000          Low Fat          0.01605
# 1           DRC01      5.92000          Regular          0.01928
# 2           FDN15     17.50000          Low Fat          0.01676
# 3           FDX07     19.20000          Regular          0.00000
# 4           NCD19      8.93000          Low Fat          0.00000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy 249.80920            OUT049
# 1            Soft Drinks  48.26920            OUT018
# 2                   Meat 141.61800            OUT049
# 3  Fruits and Vegetables 182.09500            OUT010
# 4              Household  53.86140            OUT013
#
#   Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                      1999      Medium               Tier 1
# 1                      2009      Medium               Tier 3
# 2                      1999      Medium               Tier 1
# ...
